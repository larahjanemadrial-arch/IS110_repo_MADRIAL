# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
name = input('Who are you?')
print('Welcome',name)
# Out:
# Who are you?larah
# Welcome larah

# %%
inp = input('Europe floor?')
usf = int(inp) + 1
print('US floor', usf)
# Out:
# Europe floor?0
# US floor 1

# %%
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Enter your name: larah
# Hello larah

# %%
hours = input('Enter Hours: ')
rate = input('Enter Rate: ')
pay = float(hours) * float(rate)
print('Pay:', pay)
# Out:
# Enter Hours: 72
# Enter Rate: 1.2
# Pay: 86.39999999999999

# %%
inp = input('Enter a number: ')
num = float(inp)
square = num ** 2
print('The square is:', square)
# Out:
# Enter a number: 11
# The square is: 121.0

# %%
inp = input('Enter a number: ')
num = float(inp)
square = num ** 2
print('The square is:', square)
# Out:
# Enter a number: 3
# The square is: 9.0

# %%
celsius = input('Enter Celsius temperature: ')
fahr = (float(celsius) * 9/5) + 32
print('Fahrenheit temperature:', fahr)
# Out:
# Enter Celsius temperature: 22
# Fahrenheit temperature: 71.6

# %%
with open("/content/drive/MyDrive/answers_chapter_2.txt", "w") as f:
    f.write(code)
print("All code has been written into answers_chapter_2.txt")
# Out:
# All code has been written into answers_chapter_2.txt
