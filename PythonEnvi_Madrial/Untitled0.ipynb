# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/IS110_BPERFORMANCE_MADRIAL/PythonEnvi_Madrial
# Out:
# /content/drive/MyDrive/IS110_BPERFORMANCE_MADRIAL/PythonEnvi_Madrial

# %%
# !pwd
#path for the working directory
# Out:
# /content/drive/MyDrive/IS110_BPERFORMANCE_MADRIAL/PythonEnvi_Madrial

# %%
# !pip install virtualenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 74.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 17.5 MB/s eta 0:00:00
# ...

# %%
# !virtualenv Eljay
# Out:
# created virtual environment CPython3.12.12.final.0-64 in 13375ms
#   creator CPython3Posix(dest=/content/drive/MyDrive/IS110_BPERFORMANCE_MADRIAL/PythonEnvi_Madrial/Eljay, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.cache/virtualenv)
#     added seed packages: funcparserlib==1.0.1, humpy==0.1.2, hy==1.2.0, numpy==2.4.2, pandas==3.0.1, pip==26.0.1, python_dateutil==2.9.0.post0, six==1.17.0
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !source Eljay/bin/activate

# %%
# %%writefile requirments.txt
# pandas
# numpy
# Out:
# Overwriting requirments.txt

# %%
# !Eljay/bin/pip install -r requirments.txt

# %%
# !Eljay/bin/pip freeze > requirments.txt

# %%
# !Eljay/bin/pip list
# Out:
# Package         Version
# --------------- -----------
# funcparserlib   1.0.1
# humpy           0.1.2
# hy              1.2.0
# numpy           2.4.2
# pandas          3.0.1
# pip             26.0.1
# python-dateutil 2.9.0.post0
# six             1.17.0

# %%
# !cat requirments.txt
# Out:
# funcparserlib==1.0.1
# humpy==0.1.2
# hy==1.2.0
# numpy==2.4.2
# pandas==3.0.1
# python-dateutil==2.9.0.post0
# six==1.17.0

# %%
import pandas as pd
import numpy as np
